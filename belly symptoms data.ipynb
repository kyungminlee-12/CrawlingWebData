# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

asan_html=urlopen("https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomSubmain.do?partId=B000010")
bsObject=BeautifulSoup(asan_html, "html.parser")

# %%
# symptom link의 상세 정보
symptom_link_data=bsObject.body.find("div", {"class":"searchCont"}).find_all('a')

# %%
# 증상 링크
symptom_def_urls=[]
for i in range(len(symptom_link_data)):
    link=symptom_link_data[i].get('href')
    symptom_def_urls.append('https://www.amc.seoul.kr'+link)
print(symptom_def_urls)
# Out:
# ['https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000381', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000382', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000383', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000384', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000385', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000386', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000387', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000388', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000389', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000390', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000438', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000391', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS00954', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000437', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000392', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000393', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000394', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000395', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000396', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000397', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000398', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000399', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000400', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000401', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000402', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000403', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000404', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000405', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000406', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000407', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000408', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000409', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000410', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000411', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000492', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000412', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000439', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000413', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000414', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000415', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000416', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS00955', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000417', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000418', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomDetail.do?symptomId=SS000419', 'https://www.amc.seoul.kr/asan/healthinfo ...

# %%
# 증상 이름 
symptom_names=[]
for i in range(len(symptom_link_data)):
    name=symptom_link_data[i].get_text()
    symptom_names.append(name)
print(symptom_names)
# Out:
# ['가슴 쓰림', '간기능 저하', '간부전', '간비대', '공복감', '구토', '급성 신부전', '농신증', '담도감염', '담석', '덩어리가 만져짐', '만성 신부전', '명치 부위 통증', '무통증', '문맥성고혈압', '배꼽의 고름 및 피', '배꼽이 솟음', '복벽이 움푹 들어감', '복부 불편감', '복부 압박 증상', '복부 통증', '복부경련', '복부비만', '복부의 박동감', '복부팽만감', '복수', '분출성 구토', '비장비대', '산통', '소화불량', '손가락으로 밀면 들어감', '식후 불쾌감', '십이지장궤양', '아랫배가 뭉침', '악취', '안정 시 탈장 사라짐', '압통', '야뇨증', '양수의 감소', '옆구리 통증', '오심', '우하복부 통증', '위궤양', '위산의 역류', '위염', '위의 연동운동이 보임', '위장관 출혈', '위장관의 허혈', '임신 2, 3기의 오심', '임신 오조증', '잔변감', '장마비', '장폐색', '초록색 구토', '탈장', '탈장 돌출', '탈장 부위의 통증', '토혈', '트림', '포만감', '헛배', '흡수장애']

# %%
# 증상 id
symptom_ids=[]
for i in range(len(symptom_link_data)):
    id_name="cont1_"+str(i+1)
    symptom_id=bsObject.body.find("input", {'id':id_name}).get('value')
    symptom_ids.append(symptom_id)
print(symptom_ids)
# Out:
# ['SS000381', 'SS000382', 'SS000383', 'SS000384', 'SS000385', 'SS000386', 'SS000387', 'SS000388', 'SS000389', 'SS000390', 'SS000438', 'SS000391', 'SS00954', 'SS000437', 'SS000392', 'SS000393', 'SS000394', 'SS000395', 'SS000396', 'SS000397', 'SS000398', 'SS000399', 'SS000400', 'SS000401', 'SS000402', 'SS000403', 'SS000404', 'SS000405', 'SS000406', 'SS000407', 'SS000408', 'SS000409', 'SS000410', 'SS000411', 'SS000492', 'SS000412', 'SS000439', 'SS000413', 'SS000414', 'SS000415', 'SS000416', 'SS00955', 'SS000417', 'SS000418', 'SS000419', 'SS000420', 'SS000421', 'SS000422', 'SS000423', 'SS000424', 'SS000425', 'SS000426', 'SS000427', 'SS000428', 'SS000429', 'SS000430', 'SS000431', 'SS000432', 'SS000433', 'SS000434', 'SS000435', 'SS000436']

# %%
belly_symptoms = dict(zip(symptom_ids, symptom_names))
print('증상 수:',len(belly_symptoms))
print(belly_symptoms)
# Out:
# 증상 수: 62
# {'SS000381': '가슴 쓰림', 'SS000382': '간기능 저하', 'SS000383': '간부전', 'SS000384': '간비대', 'SS000385': '공복감', 'SS000386': '구토', 'SS000387': '급성 신부전', 'SS000388': '농신증', 'SS000389': '담도감염', 'SS000390': '담석', 'SS000438': '덩어리가 만져짐', 'SS000391': '만성 신부전', 'SS00954': '명치 부위 통증', 'SS000437': '무통증', 'SS000392': '문맥성고혈압', 'SS000393': '배꼽의 고름 및 피', 'SS000394': '배꼽이 솟음', 'SS000395': '복벽이 움푹 들어감', 'SS000396': '복부 불편감', 'SS000397': '복부 압박 증상', 'SS000398': '복부 통증', 'SS000399': '복부경련', 'SS000400': '복부비만', 'SS000401': '복부의 박동감', 'SS000402': '복부팽만감', 'SS000403': '복수', 'SS000404': '분출성 구토', 'SS000405': '비장비대', 'SS000406': '산통', 'SS000407': '소화불량', 'SS000408': '손가락으로 밀면 들어감', 'SS000409': '식후 불쾌감', 'SS000410': '십이지장궤양', 'SS000411': '아랫배가 뭉침', 'SS000492': '악취', 'SS000412': '안정 시 탈장 사라짐', 'SS000439': '압통', 'SS000413': '야뇨증', 'SS000414': '양수의 감소', 'SS000415': '옆구리 통증', 'SS000416': '오심', 'SS00955': '우하복부 통증', 'SS000417': '위궤양', 'SS000418': '위산의 역류', 'SS000419': '위염', 'SS000420': '위의 연동운동이 보임', 'SS000421': '위장관 출혈', 'SS000422': '위장관의 허혈', 'SS000423': '임신 2, 3기의 오심', 'SS000424': '임신 오조증', 'SS000425': '잔변감', 'SS000426': '장마비', 'SS000427': '장폐색', 'SS000428': '초록색 구토', 'SS000429': '탈장', 'SS000430': '탈장 돌출', 'SS000431': '탈장 부위의 통증', 'SS000432': '토혈', 'SS000433': '트림', 'SS000434': '포만감', 'SS000435': '헛배', 'SS000436': '흡수장애'}

# %%
belly_symptoms.pop('SS000382')  # 간 기능 저하
belly_symptoms.pop('SS000383')  # 간 부전
belly_symptoms.pop('SS000384')  # 간비대
belly_symptoms.pop('SS000387')  # 급성 신부전
belly_symptoms.pop('SS000388')  # 농신증
belly_symptoms.pop('SS000389')  # 담도감염
belly_symptoms.pop('SS000390')  # 담석
belly_symptoms.pop('SS000391')  # 만성 신부전
belly_symptoms.pop('SS000392')  # 문맥성고혈압

belly_symptoms.pop('SS000400')  # 복부비만
belly_symptoms.pop('SS000401')  # 복부의 박동감
belly_symptoms.pop('SS000403')  # 복수
belly_symptoms.pop('SS000406')  # 산통
belly_symptoms.pop('SS000414')  # 양수의 감소

belly_symptoms.pop('SS000412')  # 오심
belly_symptoms.pop('SS000416')  # 오심
belly_symptoms.pop('SS000419')  # 위염
belly_symptoms.pop('SS000417')  # 위궤양
belly_symptoms.pop('SS000405')  # 비장비대
belly_symptoms.pop('SS000410')  # 십이지장궤양
belly_symptoms.pop('SS000420')  # 위의 연동운동이 보임
belly_symptoms.pop('SS000421')  # 위장관 출혈
belly_symptoms.pop('SS000422')  # 위장관의 허혈
belly_symptoms.pop('SS000423')  # 임신 2, 3기의 오심
belly_symptoms.pop('SS000424')  # 임신 오조증

belly_symptoms.pop('SS000426')  # 장마비
belly_symptoms.pop('SS000427')  # 장폐색
belly_symptoms.pop('SS000429')  # 탈장
belly_symptoms.pop('SS000436')  # 흡수장애

# 아래 증상들은 예상되는 병명이 없어서 제거합니다
# 명치 부위 통증, 무통증, 우하복부 통증, 위산의 역류햐
belly_symptoms.pop('SS00954')  # 명치 부위 통증
belly_symptoms.pop('SS000437')  # 무통증
belly_symptoms.pop('SS00955')  # 우하복부 통증
belly_symptoms.pop('SS000418')  # 위산의 역류

print('증상 수:',len(belly_symptoms))
print('증상 수:',belly_symptoms)
# Out:
# 증상 수: 29
# 증상 수: {'SS000381': '가슴 쓰림', 'SS000385': '공복감', 'SS000386': '구토', 'SS000438': '덩어리가 만져짐', 'SS000393': '배꼽의 고름 및 피', 'SS000394': '배꼽이 솟음', 'SS000395': '복벽이 움푹 들어감', 'SS000396': '복부 불편감', 'SS000397': '복부 압박 증상', 'SS000398': '복부 통증', 'SS000399': '복부경련', 'SS000402': '복부팽만감', 'SS000404': '분출성 구토', 'SS000407': '소화불량', 'SS000408': '손가락으로 밀면 들어감', 'SS000409': '식후 불쾌감', 'SS000411': '아랫배가 뭉침', 'SS000492': '악취', 'SS000439': '압통', 'SS000413': '야뇨증', 'SS000415': '옆구리 통증', 'SS000425': '잔변감', 'SS000428': '초록색 구토', 'SS000430': '탈장 돌출', 'SS000431': '탈장 부위의 통증', 'SS000432': '토혈', 'SS000433': '트림', 'SS000434': '포만감', 'SS000435': '헛배'}

# %%
# 각 증상 선택 결과 link
res_links=[]
for idx in belly_symptoms:
    res_link='https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds='+idx
    res_links.append(res_link)
print(res_links)
print("개수: ", len(res_links))
# Out:
# ['https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000381', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000385', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000386', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000438', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000393', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000394', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000395', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000396', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000397', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000398', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000399', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000402', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000404', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000407', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000408', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000409', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000411', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000492', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000439', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000413', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000415', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000425', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000428', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000430', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000431', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000432', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000433', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000434', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B0000010&symptomIds=SS000435']
# 개수:  29

# %% [markdown]
# ### 복부 증상 별 예상 병명 1개 조합의 결과

# %%
sympt_names=belly_symptoms.values()
print(sympt_names)
print("\n\n")

i=0
for idx in belly_symptoms:
    sympt_res_html=urlopen(res_links[i])     # 추린 내용
    i=i+1
    sympt_res_Object=BeautifulSoup(sympt_res_html, "html.parser")
    # print(sympt_res_Object)
    
    # symptom result link의 상세 정보
    symptom_res_link_data=sympt_res_Object.body.find_all("strong", {"class":"contTitle"})
    print('선택된 증상 이름: ', belly_symptoms[idx])   # ㅣist(belly_symptoms.values())[0]
    res_names=[]
    for j in range(len(symptom_res_link_data)):
        # name=symptom_link_data[i].get_text()
        res_names.append(symptom_res_link_data[j].get_text().strip())
    print('예상 질병 이름: ', end='')
    print(res_names)
    print()
# Out:
# dict_values(['가슴 쓰림', '공복감', '구토', '덩어리가 만져짐', '배꼽의 고름 및 피', '배꼽이 솟음', '복벽이 움푹 들어감', '복부 불편감', '복부 압박 증상', '복부 통증', '복부경련', '복부팽만감', '분출성 구토', '소화불량', '손가락으로 밀면 들어감', '식후 불쾌감', '아랫배가 뭉침', '악취', '압통', '야뇨증', '옆구리 통증', '잔변감', '초록색 구토', '탈장 돌출', '탈장 부위의 통증', '토혈', '트림', '포만감', '헛배'])
#
#
#
# 선택된 증상 이름:  가슴 쓰림
# 예상 질병 이름: ["바렛 식도(Barrett's esophagus)", '소화불량(Dyspepsia)', '신체형 장애(Somatic symptom disorder)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '오래된 심근경색증(Old myocardial infarction)', '위궤양(Gastric ulcer)', '위식도 역류성 질환(Gastro-esophagus reflux disease)', '협심증(Angina pectoris)']
#
# 선택된 증상 이름:  공복감
# 예상 질병 이름: ['저혈당증(Hypoglycemia)']
#
# 선택된 증상 이름:  구토
# 예상 질병 이름: ['간농양(Liver abscess)', '간염(Hepatitis)', '간의 양성 신생물(Benign neoplasm of the liver)', '고마그네슘혈증(Hypermagnesemia)', '고산병(Mountain sickness)', '고칼륨혈증(Hyperkalemia)', '고칼슘혈증(Hypercalcemia)', '고환의 염전(Torsion of testis)', '광견병(Rabies)', '교모세포종(Glioblastoma)', '급성 A형 간염(Acute hepatitis A)', '급성 B형 간염(Acute hepatitis B)', '급성 담낭염(Acute cholecystitis)', '급성 바이러스성 간염(Acute viral hepatitis)', '급성 신부전(Acute renal failure)', '급성 신우신염(Acute pyelonephritis)', '급성 심근경색증(Acute myocardial infarction)', '급성 위장염(Acute gastroenteritis)', '급성 충수염(Acute appendicitis)', '급성 췌장염(Acute pancreatitis)']
#
# 선택된 증상 이름:  덩어리가 만져짐
# 예상 질병 이름: ['간세포성 암종(Hepatocellular carcinoma)', '갑상선 유두암(Papillary Carcinoma of Thyroid )', '갑상선암(Thyroid cancer)', '결절종(Ganglion)', '골육종(Osteosarcoma)', '과립막 세포종(Granulosa cell tumor)', '구강암(Oral Cancer)', '난소암(Ovarian cancer)', "듀피트렌 구축(Dupuytren's contracture)", '린치 증후군(Lynch Syndrome)', '림프관종(Lymphangioma)', '림프종(Lymphoma)', '방광암(Bladder cancer)', '버킷 림프종(Burkitt Tumor)', '부갑상선암(Parathyroid Cancer)', '비호지킨 림프종(Non-Hodgkin lymphoma)', '뼈의 신생물(Neoplasm of the bone)', '생식선 및 생식 세포의 신생물(Gonadal and germ cell neoplasma)', '수신증(Hydronephrosis)', '연부조직 육종(Soft tissue sarcoma)']
#
# 선택된 증상 이름:  배꼽의 고름 및 피
# 예상 질병 이름: ['배꼽염(Omphalitis)']
#
# 선택된 증상 이름:  배꼽이 솟음
# 예상 질병 이름: ['제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  복벽이 움푹 들어감
# 예상 질병 이름: ['횡격막 탈장(Diaphragmatic hernia)']
#
# 선택된 증상 이름:  복부 불편감
# 예상 질병 이름: ['간 혈관종(Hepatic hemangioma)', '간경화(Liver cirrhosis)', '간염(Hepatitis)', '급성 C형 간염(Acute hepatitis C)', '냉방병(Air-conditioningitis)', '노로바이러스 장염(Norovirus Gastroenteritis)', '만성 C형 간염(Chronic hepatitis C)', '만성 담낭염(Chronic cholecystitis)', '부신암(Adrenal gland cancer)', '불안 장애(Anxiety disorder)', '섬유근육통(Fibromyalgia)', '소장암(Small bowel cancer)', '위암(Stomach cancer)', '위염(Gastritis)', '유당분해효소결핍증(Lactose intolerance)', '장간막 동맥 혈전증(Mesenteric Arterial Thrombosis)', '장간막 정맥 혈전증(Mesenteric Venous Thrombosis)', '조기 위암(Early gastric cancer)', '지방간(Fatty liver)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부 압박 증상
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '난소 낭종(Ovarian cysts)', '만성 위염(Chronic gastritis)', '자궁 탈출증(Uterine Prolapse)', '조산(Prematurity delivery)']
#
# 선택된 증상 이름:  복부 통증
# 예상 질병 이름: ['가와사키병(Kawasaki Disease)', '간 전이(Liver Metastasis)', '간내 담석(IHD stone)', '간농양(Liver abscess)', '간디스토마(Clonorchisis sinensis)', '간세포성 암종(Hepatocellular carcinoma)', '간의 양성 신생물(Benign neoplasm of the liver)', '간이식 후 상태(Liver Transplantation status)', '간질성 방광염(Interstitial Cystitis)', '게실 질환(Diverticular disease)', '결핵성 복막염(Tuberculous peritonitis)', '경화성 담관염(Sclerosing cholangitis)', '계류 유산(Missed abortion)', '골반 염증성 질환(Pelvic inflammatory disease)', '과립막 세포종(Granulosa cell tumor)', '과호흡 증후군(Hyperventilation syndrome)', '궤양성 대장염(Ulcerative colitis)', '급성 A형 간염(Acute hepatitis A)', '급성 담낭염(Acute cholecystitis)', '급성 류마티스성 열(Acute Rheumatic fever)']
#
# 선택된 증상 이름:  복부경련
# 예상 질병 이름: ['대사성 산증(Metabolic Acidosis)', '복막염(Peritonitis)', '자궁경관무력증(Incompetent internal os of cervix)', '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)', '조산(Prematurity delivery)', '혈관부종(Angioedema)']
#
# 선택된 증상 이름:  복부팽만감
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '게실 질환(Diverticular disease)', '결핵성 복막염(Tuberculous peritonitis)', '과호흡 증후군(Hyperventilation syndrome)', '급성 위장염(Acute gastroenteritis)', '급성 췌장염(Acute pancreatitis)', '기능성 위장 장애(Functional Gastrointestinal Disorder)', '난소의 양성 종양(Benign ovary tumor)', '납 중독(Lead Poisoning)', '덤핑 증후군(Dumping syndrome)', '만성 위염(Chronic gastritis)', '무월경(Amenorrhea)', '반흔 탈장(Incisonal hernia)', '변비(Constipation)', '복막염(Peritonitis)', '복부 대동맥류(Abdominal aortic Aneurysm)', '부신암(Adrenal gland cancer)', '선천성 거대결장증(Hirschsprung disease)', '선천성 소장 결손, 폐쇄 및 협착(Congenital absence, atresia and stenosis of intestine)', '소장암(Small bowel cancer)']
#
# 선택된 증상 이름:  분출성 구토
# 예상 질병 이름: ['영아 비대성 유문협착증(IHPS (infantile hypertrophic pyloric stenosis))']
#
# 선택된 증상 이름:  소화불량
# 예상 질병 이름: ['간내 담석(IHD stone)', '간디스토마(Clonorchisis sinensis)', '기능성 위장 장애(Functional Gastrointestinal Disorder)', '냉방병(Air-conditioningitis)', '담석(GB stone)', '대장암(Colon cancer)', '만성 C형 간염(Chronic hepatitis C)', '만성 위염(Chronic gastritis)', '식도의 평활근종(Leiomyoma of esophagus)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '양수과다증(Hydramnios)', '위 유암종(Gastric Carcinoid Tumor)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위용종(Gastric polyp)', '자가면역 질환(autoimmune diseasse)', '장유착(Intestine adhesions)', '전신 경화증(Systemic Sclerosis)', '조기 위암(Early gastric cancer)']
#
# 선택된 증상 이름:  손가락으로 밀면 들어감
# 예상 질병 이름: ['제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  식후 불쾌감
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  아랫배가 뭉침
# 예상 질병 이름: ['조기 진통(Preterm labour)']
#
# 선택된 증상 이름:  악취
# 예상 질병 이름: ['골반 염증성 질환(Pelvic inflammatory disease)', '급성 질염(Acute vaginitis)', '배꼽염(Omphalitis)', '복압성 요실금(Stress urinary incontinence)', '외이도염(Otitis externa)', '자궁 상피 내 암종(Carcinoma in situ of Cervix)', '자궁경부암(Cervical cancer)', '진주종(Cholesteatoma)']
#
# 선택된 증상 이름:  압통
# 예상 질병 이름: ['간농양(Liver abscess)', '감염성 근육염(Infective myositis)', '감염성 단핵구증(Infectious mononucleosis)', '결핵성 복막염(Tuberculous peritonitis)', '경부 림프절염(Cervical lymphadenitis)', '관절염(Arthritis)', '근근막 통증 증후군(myofascial pain syndrome)', '근육 긴장성 두통(Tension-type headache)', '두통(Headache)', '맹장염(Appendicitis)', '봉와직염(Cellulitis)', '비루관 폐쇄(Nasolacrimal duct obstruction)', '석회성 건염(Calcific Tendinitis)', '스티븐 존슨 증후군(Stevens Johnson syndrome)', '슬개건염(Patellar tendinitis)', '슬개골 골절(Patella Fracture)', '오스굿씨 병(Osgood Schlatter Disease)', '융모양막염(Chorioamnionitis)', '조갑주위염(Paronychia)', '족저 근막염(Plantar Fasciitis)']
#
# 선택된 증상 이름:  야뇨증
# 예상 질병 이름: ['야뇨증(Enuresis)', '울혈성 심부전(Congestive heart failure)']
#
# 선택된 증상 이름:  옆구리 통증
# 예상 질병 이름: ['낭성 신장 질환(Cystic kidney disease)', '맹장염(Appendicitis)', '면역글로불린 A 신병증(IgA nephropathy)', '방광암(Bladder cancer)', '신세포암종(Renal cell carcinoma)', '신우요관 폐색(UPJ obstruction)', '신우요관암(Renal pelvis cancer)', '신장 결석(Renal stone)', '요관 결석(Ureteral stone)', '요관 협착(Ureteral stricture)', '요로 감염(Urinary tract infection)', '요로결석(Urolithiasis)', '혈뇨(Hematuria)']
#
# 선택된 증상 이름:  잔변감
# 예상 질병 이름: ['대장암(Colon cancer)', '변비(Constipation)', '아메바성 이질(Amebic dysentery)', '항문 및 직장의 궤양(Ulcer of anus and rectum)']
#
# 선택된 증상 이름:  초록색 구토
# 예상 질병 이름: ['선천성 소장 결손, 폐쇄 및 협착(Congenital absence, atresia and stenosis of intestine)']
#
# 선택된 증상 이름:  탈장 돌출
# 예상 질병 이름: ['반흔 탈장(Incisonal hernia)', '재발성 탈장(Recurrent hernia)', '제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  탈장 부위의 통증
# 예상 질병 이름: ['반흔 탈장(Incisonal hernia)', '재발성 탈장(Recurrent hernia)', '제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  토혈
# 예상 질병 이름: ['만성 위염(Chronic gastritis)', '말로리-바이스 증후군(Mallory-weiss Syndrome)', "바렛 식도(Barrett's esophagus)", '식도 정맥류(Esophageal varices)', '식도암(Esophageal cancer)', '식도염(Esophagitis)', '식도의 평활근종(Leiomyoma of esophagus)', '십이지장 궤양(Duodenal ulcer)', '위 정맥류(Gastric varices)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위장관 기질 종양(Stomach GIST)', '위장관 출혈(Gastrointestinal hemorrhage)', '조기 위암(Early gastric cancer)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  트림
# 예상 질병 이름: ['기능성 위장 장애(Functional Gastrointestinal Disorder)', '소화불량(Dyspepsia)', '식도이완불능증(Esophageal Achalasia)', '십이지장염(Duodenitis)']
#
# 선택된 증상 이름:  포만감
# 예상 질병 이름: ['간 혈관종(Hepatic hemangioma)', '소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  헛배
# 예상 질병 이름: ['대동맥 박리(Aortic dissection)']

# %% [markdown]
# ### 2개씩 조합

# %%
from itertools import permutations

two_belly_symtoms=list(permutations(list(belly_symptoms), 2))

# %%
# 각 증상 선택 결과 link
res_links_2=[]
for idx in two_belly_symtoms:
    res_link='https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds='+str(idx[0])+'&symptomIds='+str(idx[1])
    res_links_2.append(res_link)
print(res_links_2)
print("개수: ", len(res_links_2))
# Out:
# ['https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000385', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000386', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000438', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000393', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000394', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000395', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000396', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000397', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000398', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000399', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000402', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000404', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000407', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000408', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000409', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000411', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000492', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000439', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000413', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000415', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000425', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000428', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000430', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000431', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000432', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000433', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000434', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000381&symptomIds=SS000435', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000385&symptomIds=SS000381', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds=SS000385&symptomIds=SS000386', 'https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?sear ...
# 개수:  812

# %%
i=0
for idx in two_belly_symtoms:
    sympt_res_html=urlopen(res_links_2[i])     # 추린 내용
    i=i+1
    sympt_res_Object=BeautifulSoup(sympt_res_html, "html.parser")
    # print(sympt_res_Object)
    
    # symptom result link의 상세 정보
    symptom_res_link_data=sympt_res_Object.body.find_all("strong", {"class":"contTitle"})
    print('선택된 증상 이름: ', belly_symptoms[idx[0]]+'과', belly_symptoms[idx[1]])   # ㅣist(belly_symptoms.values())[0]
    res_names=[]
    for j in range(len(symptom_res_link_data)):
        # name=symptom_link_data[i].get_text()
        res_names.append(symptom_res_link_data[j].get_text().strip())
    print('예상 질병 이름: ', end='')
    print(res_names)
    print()
# Out:
# 선택된 증상 이름:  가슴 쓰림과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 구토
# 예상 질병 이름: ['소화불량(Dyspepsia)', '신체형 장애(Somatic symptom disorder)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)']
#
# 선택된 증상 이름:  가슴 쓰림과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 복부 통증
# 예상 질병 이름: ['소화불량(Dyspepsia)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)']
#
# 선택된 증상 이름:  가슴 쓰림과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 복부팽만감
# 예상 질병 이름: ['신체형 장애(Somatic symptom disorder)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)']
#
# 선택된 증상 이름:  가슴 쓰림과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 소화불량
# 예상 질병 이름: ['십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)']
#
# 선택된 증상 이름:  가슴 쓰림과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 식후 불쾌감
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  가슴 쓰림과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  가슴 쓰림과 토혈
# 예상 질병 이름: ["바렛 식도(Barrett's esophagus)", '십이지장 궤양(Duodenal ulcer)', '위궤양(Gastric ulcer)']
#
# 선택된 증상 이름:  가슴 쓰림과 트림
# 예상 질병 이름: ['소화불량(Dyspepsia)', '십이지장염(Duodenitis)']
#
# 선택된 증상 이름:  가슴 쓰림과 포만감
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  가슴 쓰림과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 복부 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  공복감과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 가슴 쓰림
# 예상 질병 이름: ['소화불량(Dyspepsia)', '신체형 장애(Somatic symptom disorder)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)']
#
# 선택된 증상 이름:  구토과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 덩어리가 만져짐
# 예상 질병 이름: ['생식선 및 생식 세포의 신생물(Gonadal and germ cell neoplasma)', '위장관 기질 종양(Stomach GIST)', '장중첩증(Intussusception)', '총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  구토과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 복부 불편감
# 예상 질병 이름: ['간염(Hepatitis)', '노로바이러스 장염(Norovirus Gastroenteritis)', '만성 담낭염(Chronic cholecystitis)', '위암(Stomach cancer)', '위염(Gastritis)', '장간막 정맥 혈전증(Mesenteric Venous Thrombosis)', '진행성 위암(Advanced gastric cancer)', '총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  구토과 복부 압박 증상
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)']
#
# 선택된 증상 이름:  구토과 복부 통증
# 예상 질병 이름: ['간농양(Liver abscess)', '간의 양성 신생물(Benign neoplasm of the liver)', '급성 A형 간염(Acute hepatitis A)', '급성 담낭염(Acute cholecystitis)', '급성 바이러스성 간염(Acute viral hepatitis)', '급성 위장염(Acute gastroenteritis)', '급성 충수염(Acute appendicitis)', '급성 췌장염(Acute pancreatitis)', '납 중독(Lead Poisoning)', '노로바이러스 장염(Norovirus Gastroenteritis)', '담낭암(GB cancer)', '담석(GB stone)', '대동맥 박리(Aortic dissection)', '대장균 감염(Escherichia coli (E. coli) infection)', '덤핑 증후군(Dumping syndrome)', '독성 간염(Toxic hepatitis)', '만성 B형 간염(Chronic hepatitis B)', '복막염(Peritonitis)', '부신 기능부전(Adrenal insufficiency)', '석회화 담낭(Porcelain GB)']
#
# 선택된 증상 이름:  구토과 복부경련
# 예상 질병 이름: ['복막염(Peritonitis)']
#
# 선택된 증상 이름:  구토과 복부팽만감
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '급성 위장염(Acute gastroenteritis)', '급성 췌장염(Acute pancreatitis)', '납 중독(Lead Poisoning)', '덤핑 증후군(Dumping syndrome)', '복막염(Peritonitis)', '선천성 거대결장증(Hirschsprung disease)', '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)', '신체형 장애(Somatic symptom disorder)', '십이지장염(Duodenitis)', '요관 결석(Ureteral stone)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '이소성 췌장(Ectopic pancreas)', '장염전(Volvulus)', '장폐색(Intestinal obstruction)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  구토과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 소화불량
# 예상 질병 이름: ['담석(GB stone)', '식도의 평활근종(Leiomyoma of esophagus)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위 유암종(Gastric Carcinoid Tumor)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위용종(Gastric polyp)', '장유착(Intestine adhesions)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  구토과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 식후 불쾌감
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  구토과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 압통
# 예상 질병 이름: ['간농양(Liver abscess)', '췌장염(Pancreatitis)']
#
# 선택된 증상 이름:  구토과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 옆구리 통증
# 예상 질병 이름: ['신우요관 폐색(UPJ obstruction)', '신장 결석(Renal stone)', '요관 결석(Ureteral stone)']
#
# 선택된 증상 이름:  구토과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  구토과 토혈
# 예상 질병 이름: ['말로리-바이스 증후군(Mallory-weiss Syndrome)', '식도 정맥류(Esophageal varices)', '식도암(Esophageal cancer)', '식도염(Esophagitis)', '식도의 평활근종(Leiomyoma of esophagus)', '십이지장 궤양(Duodenal ulcer)', '위 정맥류(Gastric varices)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위장관 기질 종양(Stomach GIST)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  구토과 트림
# 예상 질병 이름: ['소화불량(Dyspepsia)', '십이지장염(Duodenitis)']
#
# 선택된 증상 이름:  구토과 포만감
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  구토과 헛배
# 예상 질병 이름: ['대동맥 박리(Aortic dissection)']
#
# 선택된 증상 이름:  덩어리가 만져짐과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 구토
# 예상 질병 이름: ['생식선 및 생식 세포의 신생물(Gonadal and germ cell neoplasma)', '위장관 기질 종양(Stomach GIST)', '장중첩증(Intussusception)', '총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  덩어리가 만져짐과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 복부 불편감
# 예상 질병 이름: ['총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  덩어리가 만져짐과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 복부 통증
# 예상 질병 이름: ['간세포성 암종(Hepatocellular carcinoma)', '과립막 세포종(Granulosa cell tumor)', '난소암(Ovarian cancer)', '버킷 림프종(Burkitt Tumor)', '위장관 기질 종양(Stomach GIST)', '윌름즈 종양(Wilms Tumor)', '자궁선근증(Adenomyosis)', '장중첩증(Intussusception)', '총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  덩어리가 만져짐과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 압통
# 예상 질병 이름: ['표피낭종(Epidermal cyst)']
#
# 선택된 증상 이름:  덩어리가 만져짐과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 옆구리 통증
# 예상 질병 이름: ['방광암(Bladder cancer)']
#
# 선택된 증상 이름:  덩어리가 만져짐과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 토혈
# 예상 질병 이름: ['위장관 기질 종양(Stomach GIST)']
#
# 선택된 증상 이름:  덩어리가 만져짐과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  덩어리가 만져짐과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 복부 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 복부팽만감
# 예상 질병 이름: []
# 선택된 증상 이름:  배꼽의 고름 및 피과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 악취
# 예상 질병 이름: ['배꼽염(Omphalitis)']
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽의 고름 및 피과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 복부 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 손가락으로 밀면 들어감
# 예상 질병 이름: ['제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  배꼽이 솟음과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 탈장 돌출
# 예상 질병 이름: ['제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  배꼽이 솟음과 탈장 부위의 통증
# 예상 질병 이름: ['제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  배꼽이 솟음과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  배꼽이 솟음과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 복부 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복벽이 움푹 들어감과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 구토
# 예상 질병 이름: ['간염(Hepatitis)', '노로바이러스 장염(Norovirus Gastroenteritis)', '만성 담낭염(Chronic cholecystitis)', '위암(Stomach cancer)', '위염(Gastritis)', '장간막 정맥 혈전증(Mesenteric Venous Thrombosis)', '진행성 위암(Advanced gastric cancer)', '총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  복부 불편감과 덩어리가 만져짐
# 예상 질병 이름: ['총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  복부 불편감과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 복부 통증
# 예상 질병 이름: ['노로바이러스 장염(Norovirus Gastroenteritis)', '섬유근육통(Fibromyalgia)', '소장암(Small bowel cancer)', '위암(Stomach cancer)', '위염(Gastritis)', '유당분해효소결핍증(Lactose intolerance)', '장간막 동맥 혈전증(Mesenteric Arterial Thrombosis)', '장간막 정맥 혈전증(Mesenteric Venous Thrombosis)', '진행성 위암(Advanced gastric cancer)', '총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  복부 불편감과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 복부팽만감
# 예상 질병 이름: ['부신암(Adrenal gland cancer)', '소장암(Small bowel cancer)', '위암(Stomach cancer)', '유당분해효소결핍증(Lactose intolerance)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부 불편감과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 소화불량
# 예상 질병 이름: ['냉방병(Air-conditioningitis)', '만성 C형 간염(Chronic hepatitis C)', '위암(Stomach cancer)', '조기 위암(Early gastric cancer)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부 불편감과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 토혈
# 예상 질병 이름: ['위암(Stomach cancer)', '조기 위암(Early gastric cancer)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부 불편감과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 불편감과 포만감
# 예상 질병 이름: ['간 혈관종(Hepatic hemangioma)']
#
# 선택된 증상 이름:  복부 불편감과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 구토
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)']
#
# 선택된 증상 이름:  복부 압박 증상과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 복부 통증
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '난소 낭종(Ovarian cysts)', '만성 위염(Chronic gastritis)', '조산(Prematurity delivery)']
#
# 선택된 증상 이름:  복부 압박 증상과 복부경련
# 예상 질병 이름: ['조산(Prematurity delivery)']
#
# 선택된 증상 이름:  복부 압박 증상과 복부팽만감
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '만성 위염(Chronic gastritis)']
#
# 선택된 증상 이름:  복부 압박 증상과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 소화불량
# 예상 질병 이름: ['만성 위염(Chronic gastritis)']
#
# 선택된 증상 이름:  복부 압박 증상과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 토혈
# 예상 질병 이름: ['만성 위염(Chronic gastritis)']
#
# 선택된 증상 이름:  복부 압박 증상과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 압박 증상과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 가슴 쓰림
# 예상 질병 이름: ['소화불량(Dyspepsia)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)']
#
# 선택된 증상 이름:  복부 통증과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 구토
# 예상 질병 이름: ['간농양(Liver abscess)', '간의 양성 신생물(Benign neoplasm of the liver)', '급성 A형 간염(Acute hepatitis A)', '급성 담낭염(Acute cholecystitis)', '급성 바이러스성 간염(Acute viral hepatitis)', '급성 위장염(Acute gastroenteritis)', '급성 충수염(Acute appendicitis)', '급성 췌장염(Acute pancreatitis)', '납 중독(Lead Poisoning)', '노로바이러스 장염(Norovirus Gastroenteritis)', '담낭암(GB cancer)', '담석(GB stone)', '대동맥 박리(Aortic dissection)', '대장균 감염(Escherichia coli (E. coli) infection)', '덤핑 증후군(Dumping syndrome)', '독성 간염(Toxic hepatitis)', '만성 B형 간염(Chronic hepatitis B)', '복막염(Peritonitis)', '부신 기능부전(Adrenal insufficiency)', '석회화 담낭(Porcelain GB)']
#
# 선택된 증상 이름:  복부 통증과 덩어리가 만져짐
# 예상 질병 이름: ['간세포성 암종(Hepatocellular carcinoma)', '과립막 세포종(Granulosa cell tumor)', '난소암(Ovarian cancer)', '버킷 림프종(Burkitt Tumor)', '위장관 기질 종양(Stomach GIST)', '윌름즈 종양(Wilms Tumor)', '자궁선근증(Adenomyosis)', '장중첩증(Intussusception)', '총담관 낭(Choledochal cyst)']
#
# 선택된 증상 이름:  복부 통증과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 복부 불편감
# 예상 질병 이름: ['노로바이러스 장염(Norovirus Gastroenteritis)', '섬유근육통(Fibromyalgia)', '소장암(Small bowel cancer)', '위암(Stomach cancer)', '위염(Gastritis)', '유당분해효소결핍증(Lactose intolerance)', '장간막 동맥 혈전증(Mesenteric Arterial Thrombosis)', '장간막 정맥 혈전증(Mesenteric Venous Thrombosis)', '진행성 위암(Advanced gastric cancer)', '총담관 낭(Choledochal cyst)']
# 선택된 증상 이름:  복부 통증과 복부 압박 증상
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '난소 낭종(Ovarian cysts)', '만성 위염(Chronic gastritis)', '조산(Prematurity delivery)']
#
# 선택된 증상 이름:  복부 통증과 복부경련
# 예상 질병 이름: ['복막염(Peritonitis)', '자궁경관무력증(Incompetent internal os of cervix)', '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)', '조산(Prematurity delivery)']
#
# 선택된 증상 이름:  복부 통증과 복부팽만감
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '게실 질환(Diverticular disease)', '결핵성 복막염(Tuberculous peritonitis)', '과호흡 증후군(Hyperventilation syndrome)', '급성 위장염(Acute gastroenteritis)', '급성 췌장염(Acute pancreatitis)', '난소의 양성 종양(Benign ovary tumor)', '납 중독(Lead Poisoning)', '덤핑 증후군(Dumping syndrome)', '만성 위염(Chronic gastritis)', '무월경(Amenorrhea)', '변비(Constipation)', '복막염(Peritonitis)', '복부 대동맥류(Abdominal aortic Aneurysm)', '소장암(Small bowel cancer)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위장관 결핵(Gastrointestinal tuberculosis)', '유당분해효소결핍증(Lactose intolerance)']
#
# 선택된 증상 이름:  복부 통증과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 소화불량
# 예상 질병 이름: ['간내 담석(IHD stone)', '간디스토마(Clonorchisis sinensis)', '담석(GB stone)', '대장암(Colon cancer)', '만성 위염(Chronic gastritis)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위 유암종(Gastric Carcinoid Tumor)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위용종(Gastric polyp)', '장유착(Intestine adhesions)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부 통증과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 식후 불쾌감
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  복부 통증과 아랫배가 뭉침
# 예상 질병 이름: ['조기 진통(Preterm labour)']
#
# 선택된 증상 이름:  복부 통증과 악취
# 예상 질병 이름: ['골반 염증성 질환(Pelvic inflammatory disease)', '복압성 요실금(Stress urinary incontinence)', '자궁 상피 내 암종(Carcinoma in situ of Cervix)']
#
# 선택된 증상 이름:  복부 통증과 압통
# 예상 질병 이름: ['간농양(Liver abscess)', '결핵성 복막염(Tuberculous peritonitis)', '맹장염(Appendicitis)', '췌장염(Pancreatitis)']
#
# 선택된 증상 이름:  복부 통증과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 옆구리 통증
# 예상 질병 이름: ['맹장염(Appendicitis)', '요관 협착(Ureteral stricture)']
#
# 선택된 증상 이름:  복부 통증과 잔변감
# 예상 질병 이름: ['대장암(Colon cancer)', '변비(Constipation)', '아메바성 이질(Amebic dysentery)', '항문 및 직장의 궤양(Ulcer of anus and rectum)']
#
# 선택된 증상 이름:  복부 통증과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부 통증과 토혈
# 예상 질병 이름: ['만성 위염(Chronic gastritis)', '십이지장 궤양(Duodenal ulcer)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위장관 기질 종양(Stomach GIST)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부 통증과 트림
# 예상 질병 이름: ['소화불량(Dyspepsia)', '십이지장염(Duodenitis)']
#
# 선택된 증상 이름:  복부 통증과 포만감
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  복부 통증과 헛배
# 예상 질병 이름: ['대동맥 박리(Aortic dissection)']
#
# 선택된 증상 이름:  복부경련과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 구토
# 예상 질병 이름: ['복막염(Peritonitis)']
#
# 선택된 증상 이름:  복부경련과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 복부 압박 증상
# 예상 질병 이름: ['조산(Prematurity delivery)']
#
# 선택된 증상 이름:  복부경련과 복부 통증
# 예상 질병 이름: ['복막염(Peritonitis)', '자궁경관무력증(Incompetent internal os of cervix)', '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)', '조산(Prematurity delivery)']
#
# 선택된 증상 이름:  복부경련과 복부팽만감
# 예상 질병 이름: ['복막염(Peritonitis)']
#
# 선택된 증상 이름:  복부경련과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부경련과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 가슴 쓰림
# 예상 질병 이름: ['신체형 장애(Somatic symptom disorder)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)']
#
# 선택된 증상 이름:  복부팽만감과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 구토
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '급성 위장염(Acute gastroenteritis)', '급성 췌장염(Acute pancreatitis)', '납 중독(Lead Poisoning)', '덤핑 증후군(Dumping syndrome)', '복막염(Peritonitis)', '선천성 거대결장증(Hirschsprung disease)', '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)', '신체형 장애(Somatic symptom disorder)', '십이지장염(Duodenitis)', '요관 결석(Ureteral stone)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '이소성 췌장(Ectopic pancreas)', '장염전(Volvulus)', '장폐색(Intestinal obstruction)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부팽만감과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 복부 불편감
# 예상 질병 이름: ['부신암(Adrenal gland cancer)', '소장암(Small bowel cancer)', '위암(Stomach cancer)', '유당분해효소결핍증(Lactose intolerance)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부팽만감과 복부 압박 증상
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '만성 위염(Chronic gastritis)']
#
# 선택된 증상 이름:  복부팽만감과 복부 통증
# 예상 질병 이름: ['간의 양성 신생물(Benign neoplasm of the liver)', '게실 질환(Diverticular disease)', '결핵성 복막염(Tuberculous peritonitis)', '과호흡 증후군(Hyperventilation syndrome)', '급성 위장염(Acute gastroenteritis)', '급성 췌장염(Acute pancreatitis)', '난소의 양성 종양(Benign ovary tumor)', '납 중독(Lead Poisoning)', '덤핑 증후군(Dumping syndrome)', '만성 위염(Chronic gastritis)', '무월경(Amenorrhea)', '변비(Constipation)', '복막염(Peritonitis)', '복부 대동맥류(Abdominal aortic Aneurysm)', '소장암(Small bowel cancer)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위장관 결핵(Gastrointestinal tuberculosis)', '유당분해효소결핍증(Lactose intolerance)']
#
# 선택된 증상 이름:  복부팽만감과 복부경련
# 예상 질병 이름: ['복막염(Peritonitis)']
#
# 선택된 증상 이름:  복부팽만감과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 소화불량
# 예상 질병 이름: ['기능성 위장 장애(Functional Gastrointestinal Disorder)', '만성 위염(Chronic gastritis)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부팽만감과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 압통
# 예상 질병 이름: ['결핵성 복막염(Tuberculous peritonitis)']
#
# 선택된 증상 이름:  복부팽만감과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 옆구리 통증
# 예상 질병 이름: ['요관 결석(Ureteral stone)']
#
# 선택된 증상 이름:  복부팽만감과 잔변감
# 예상 질병 이름: ['변비(Constipation)']
#
# 선택된 증상 이름:  복부팽만감과 초록색 구토
# 예상 질병 이름: ['선천성 소장 결손, 폐쇄 및 협착(Congenital absence, atresia and stenosis of intestine)']
#
# 선택된 증상 이름:  복부팽만감과 탈장 돌출
# 예상 질병 이름: ['반흔 탈장(Incisonal hernia)', '재발성 탈장(Recurrent hernia)']
#
# 선택된 증상 이름:  복부팽만감과 탈장 부위의 통증
# 예상 질병 이름: ['반흔 탈장(Incisonal hernia)', '재발성 탈장(Recurrent hernia)']
#
# 선택된 증상 이름:  복부팽만감과 토혈
# 예상 질병 이름: ['만성 위염(Chronic gastritis)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  복부팽만감과 트림
# 예상 질병 이름: ['기능성 위장 장애(Functional Gastrointestinal Disorder)', '십이지장염(Duodenitis)']
#
# 선택된 증상 이름:  복부팽만감과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  복부팽만감과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 복부 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  분출성 구토과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 가슴 쓰림
# 예상 질병 이름: ['십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)']
# 선택된 증상 이름:  소화불량과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 구토
# 예상 질병 이름: ['담석(GB stone)', '식도의 평활근종(Leiomyoma of esophagus)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위 유암종(Gastric Carcinoid Tumor)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위용종(Gastric polyp)', '장유착(Intestine adhesions)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  소화불량과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 복부 불편감
# 예상 질병 이름: ['냉방병(Air-conditioningitis)', '만성 C형 간염(Chronic hepatitis C)', '위암(Stomach cancer)', '조기 위암(Early gastric cancer)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  소화불량과 복부 압박 증상
# 예상 질병 이름: ['만성 위염(Chronic gastritis)']
#
# 선택된 증상 이름:  소화불량과 복부 통증
# 예상 질병 이름: ['간내 담석(IHD stone)', '간디스토마(Clonorchisis sinensis)', '담석(GB stone)', '대장암(Colon cancer)', '만성 위염(Chronic gastritis)', '십이지장 궤양(Duodenal ulcer)', '십이지장염(Duodenitis)', '위 유암종(Gastric Carcinoid Tumor)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '위용종(Gastric polyp)', '장유착(Intestine adhesions)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  소화불량과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 복부팽만감
# 예상 질병 이름: ['기능성 위장 장애(Functional Gastrointestinal Disorder)', '만성 위염(Chronic gastritis)', '십이지장염(Duodenitis)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  소화불량과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 잔변감
# 예상 질병 이름: ['대장암(Colon cancer)']
#
# 선택된 증상 이름:  소화불량과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 토혈
# 예상 질병 이름: ['만성 위염(Chronic gastritis)', '식도의 평활근종(Leiomyoma of esophagus)', '십이지장 궤양(Duodenal ulcer)', '위궤양(Gastric ulcer)', '위암(Stomach cancer)', '조기 위암(Early gastric cancer)', '진행성 위암(Advanced gastric cancer)']
#
# 선택된 증상 이름:  소화불량과 트림
# 예상 질병 이름: ['기능성 위장 장애(Functional Gastrointestinal Disorder)', '십이지장염(Duodenitis)']
#
# 선택된 증상 이름:  소화불량과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  소화불량과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 배꼽이 솟음
# 예상 질병 이름: ['제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 복부 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 탈장 돌출
# 예상 질병 이름: ['제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 탈장 부위의 통증
# 예상 질병 이름: ['제대 탈장(Umbilical hernia)']
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  손가락으로 밀면 들어감과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 가슴 쓰림
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  식후 불쾌감과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 구토
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  식후 불쾌감과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 복부 통증
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  식후 불쾌감과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  식후 불쾌감과 트림
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  식후 불쾌감과 포만감
# 예상 질병 이름: ['소화불량(Dyspepsia)']
#
# 선택된 증상 이름:  식후 불쾌감과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 배꼽의 고름 및 피
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 복부 통증
# 예상 질병 이름: ['조기 진통(Preterm labour)']
#
# 선택된 증상 이름:  아랫배가 뭉침과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 악취
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 토혈
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 트림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 포만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  아랫배가 뭉침과 헛배
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 가슴 쓰림
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 공복감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 덩어리가 만져짐
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 배꼽의 고름 및 피
# 예상 질병 이름: ['배꼽염(Omphalitis)']
#
# 선택된 증상 이름:  악취과 배꼽이 솟음
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 복벽이 움푹 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 복부 불편감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 복부 압박 증상
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 복부 통증
# 예상 질병 이름: ['골반 염증성 질환(Pelvic inflammatory disease)', '복압성 요실금(Stress urinary incontinence)', '자궁 상피 내 암종(Carcinoma in situ of Cervix)']
#
# 선택된 증상 이름:  악취과 복부경련
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 복부팽만감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 분출성 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 소화불량
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 손가락으로 밀면 들어감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 식후 불쾌감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 아랫배가 뭉침
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 압통
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 야뇨증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 옆구리 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 잔변감
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 초록색 구토
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 탈장 돌출
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 탈장 부위의 통증
# 예상 질병 이름: []
#
# 선택된 증상 이름:  악취과 토혈
# 예상 질병 이름: []

# %% [markdown]
# ### 3개씩 조합

# %%
two_belly_symtoms=list(permutations(list(belly_symptoms), 3))

# %%
# 각 증상 선택 결과 link
res_links_3=[]
for idx in two_belly_symtoms:
    res_link='https://www.amc.seoul.kr/asan/healthinfo/symptom/symptomList.do?searchFrmPartId=B000007&symptomIds='+str(idx[0])+'&symptomIds='+str(idx[1])+'&symptomIds='+str(idx[2])
    res_links_3.append(res_link)
print(res_links_3)
print("개수: ", len(res_links_3))

# %%
i=0
for idx in two_belly_symtoms:
    sympt_res_html=urlopen(res_links_3[i])     # 추린 내용
    i=i+1
    sympt_res_Object=BeautifulSoup(sympt_res_html, "html.parser")
    # print(sympt_res_Object)
    
    # symptom result link의 상세 정보
    symptom_res_link_data=sympt_res_Object.body.find_all("strong", {"class":"contTitle"})
    print('선택된 증상 이름: ', belly_symptoms[idx[0]]+'과', belly_symptoms[idx[1]]+'과',belly_symptoms[idx[2]])   # ㅣist(belly_symptoms.values())[0]
    res_names=[]
    for j in range(len(symptom_res_link_data)):
        # name=symptom_link_data[i].get_text()
        res_names.append(symptom_res_link_data[j].get_text().strip())
    print('예상 질병 이름: ', end='')
    print(res_names)
    print()
